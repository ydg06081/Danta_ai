# %%
import pandas as pd

def read_excel_and_save_csv(xlsx_path, csv_path):
    """
    주어진 엑셀 파일(.xlsx)을 읽어서 pandas DataFrame으로 반환하고, 같은 데이터를 csv 파일로 저장합니다.
    """
    try:
        df = pd.read_excel(xlsx_path)
        print(f"파일에서 읽은 데이터:\n{df.head()}")
        df.to_csv(csv_path, index=False, encoding='utf-8-sig')
        print(f"CSV 파일로 저장되었습니다: {csv_path}")
        return df
    except Exception as e:
        print(f"엑셀 파일 읽기 또는 CSV 저장 오류: {e}")
        return None


df = read_excel_and_save_csv("NewsResult_20241001-20251001.xlsx", "news.csv")
# Out:
# /opt/conda/envs/gcloud/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 파일에서 읽은 데이터:
#          뉴스 식별자        일자    언론사        기고자  \
# 0  4.100078e+06  20251001    뉴스핌     서영욱 기자
# 1  2.100101e+06  20251001   매일경제        박소라
# 2  4.101008e+06  20251001   이데일리        안유리
# 3  2.100401e+06  20251001  메트로경제        차현정
# 4  1.600801e+06  20251001   전남일보  전남일보·연합뉴스
#
#                                                  제목     통합 분류1      통합 분류2  \
# 0      '리더십의 복귀' 이재용 회장, 애플 테슬라 이어 스타게이트까지 '연타석 홈런'     경제>반도체   IT_과학>모바일
# 1  삼성 반도체, 테슬라-애플 수주에 다시 날갯짓? 막대한 투자 부담 수율 안정 과제 산적     경제>반도체   IT_과학>모바일
# 2                      애플 "인앱결제 수수료 과도하지 않아" 규제에 반박  IT_과학>모바일     경제>경제일반
# 3        삼성 애플 장악 韓 스마트폰 시장에 도전장 던진 中...프리미엄 전략 먹힐까  IT_과학>모바일       경제>유통
# 4                       중국의 'IT기술 굴기' 뒤에는 '애플'이 있었다      국제>중국   IT_과학>모바일
#
# ...

# %%
import pandas as pd

df2 = pd.read_csv("news.csv")

# %%
df2

# %%
# "일자", "제목", "키워드", "본문", "URL" 컬럼만 추출해서 새로운 DataFrame에 저장 후, CSV로도 저장
columns_to_save = ["일자", "제목", "키워드", "본문", "URL"]
df_selected = df2[columns_to_save]
df_selected.to_csv("news_selected.csv", index=False, encoding='utf-8-sig')
print(df_selected.head())
print("news_selected.csv 파일로 저장 완료!")
# Out:
#          일자                                                제목  \
# 0  20251001      '리더십의 복귀' 이재용 회장, 애플 테슬라 이어 스타게이트까지 '연타석 홈런'
# 1  20251001  삼성 반도체, 테슬라-애플 수주에 다시 날갯짓? 막대한 투자 부담 수율 안정 과제 산적
# 2  20251001                      애플 "인앱결제 수수료 과도하지 않아" 규제에 반박
# 3  20251001        삼성 애플 장악 韓 스마트폰 시장에 도전장 던진 中...프리미엄 전략 먹힐까
# 4  20251001                       중국의 'IT기술 굴기' 뒤에는 '애플'이 있었다
#
#                                                  키워드  \
# 0  리더십,복귀,이재용,회장,애플,테슬라,스타게이트,연타석,홈런,서영욱,회장,이재용,삼...
# 1  삼성,반도체,테슬라,애플,수주,날갯짓,투자,부담,수율,안정,산적,안정,삼성전자,전반...
# 2  애플,인앱,결제,수수료,과도,규제,반박,국회,애플코리아,국감,소환,규제,강화,움직임...
# 3  삼성,애플,장악,장악,스마트폰,시장,도전장,프리미엄,전략,샤오미코리아,서울,광진구,...
# 4  중국,IT기술,애플,애플,중국,포획,신간,애플,차이나,나라,휘청,국제통화기금,IMF...
#
#                                                   본문  \
# 0  [서울=뉴스핌] 서영욱 기자 = 이재용 삼성전자 회장이 글로벌 무대에서 잇단 대형 ...
# 1  삼성전자가 반도체 사업 전반에서 다시 존재감을 키우고 있다. 메모리 초격차를 이어가...
# 2  [이데일리 안유리 기자] 애플코리아 대표가 이달 국회 국정감사에 증인으로 소환된 가...
# ...
